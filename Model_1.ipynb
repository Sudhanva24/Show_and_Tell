# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/flickr8kimagescaptions/flickr8k/captions.txt
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/3226254560_2f8ac147ea.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/214543992_ce6c0d9f9b.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/2366643786_9c9a830db8.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/3368819708_0bfa0808f8.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/2190227737_6e0bde2623.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/2752809449_632cd991b3.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/3097776588_312932e438.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/1206506157_c7956accd5.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/1319634306_816f21677f.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/2465218087_fca77998c6.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/3351493005_6e5030f596.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/2949337912_beba55698b.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/534886684_a6c9f40fa1.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/3543600125_223747ef4c.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/2174206711_11cb712a8d.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/280706862_14c30d734a.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/2100735137_05c6079537.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/3131632154_098f86f4cb.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/2236016316_f476cbbf06.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/3335375223_b4da8df523.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/929679367_ff8c7df2ee.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/241347214_5f19e7998c.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/2998024845_1529c11694.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/1317292658_ba29330a0b.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/2521938720_911ac092f7.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/3426933951_2302a941d8.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/2410399168_1462c422d4.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/2587106431_1cc0e719c6.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/2339516180_12493e8ecf.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/1827560917_c8d3c5627f.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/2623247254_3bfc795121.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/2813588204_69fe7deb14.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/3396043950_12783c5147.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/3356284586_21c6f155a5.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/618771382_459bb492e4.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/3411393875_a9ff73c67a.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/3046431231_dc48851062.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/3126795109_73920ed5dc.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/2199200615_85e4c2a602.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/1460352062_d64fb633e0.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/3590739067_58baffb3a7.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/2911238432_33ec2d8cec.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/255741044_1102982213.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/3619416477_9d18580a14.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/3165936115_cb4017d94e.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/3724718895_bd03f4a4dc.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/3122773470_b622205948.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/2447289477_e888df561d.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/3518755601_cebf11e515.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/3265864834_e0229020dd.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/2930580341_d36eec8e3c.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/3616846215_d61881b60f.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/290019324_23582048d4.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/2665461736_595c87f0a3.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/2245914678_1f82fc3d80.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/2392460773_2aa01eb340.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/543102698_38e7e38bbc.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/3163323414_d1ce127aa6.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/506738508_327efdf9c3.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/860928274_744d14f198.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/825918657_d92f1761f4.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/2658360285_a0ec74ef48.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/2903617548_d3e38d7f88.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/2611651553_61f859837e.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/747921928_48eb02aab2.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/3354489242_dd529ffa1f.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/3260214530_7179346407.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/2607462776_78e639d891.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/757332692_6866ae545c.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/3317960829_78bbfafbb6.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/486917990_72bd4069af.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/2911552402_5166bc173b.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/2079554580_f18d5c181b.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/179009558_69be522c63.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/3605061440_1d08c80a57.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/3553225222_f5ebe44af1.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/3206919175_e3a11b6874.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/2393264648_a280744f97.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/241347823_6b25c3e58e.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/2635400219_2e1a984fd3.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/3497238310_2abde3965d.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/3471841031_a949645ba8.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/3163198309_bbfe504f0a.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/3005126574_49c28ffbee.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/2533414541_362bf043bb.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/525538142_7348f0bce7.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/2987121689_f9de6c479b.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/3318995586_c2bc50b92e.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/2872743471_30e0d1a90a.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/848293676_98e73c52c1.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/2955985301_e4139bc772.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/897621891_efb1e00d1d.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/3232030272_b2480a5fe7.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/1002674143_1b742ab4b8.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/2363100645_c3423a0433.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/2987576188_f82304f394.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/2085726719_a57a75dbe5.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/2102315758_a9148a842f.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/2847615962_c330bded6e.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/3500139659_b2a60b0141.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/2205088706_d7e633e00d.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/2921670682_6a77a6c3e9.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/3226541300_6c81711e8e.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/2768972186_92787cd523.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/2172526745_649f420569.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/3182121297_38c99b2769.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/1337792872_d01a390b33.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/811663364_4b350a62ce.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/2797511323_bf20acab45.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/3344948183_5b89379585.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/574274795_57e0834e7d.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/3497224764_6e17544e0d.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/892340814_bdd61e10a4.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/2690702549_cf81da8cf6.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/3029715635_43ab414dfb.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/412203580_2c7278909c.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/2369248869_0266760c4a.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/3676460610_8c52e8a355.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/520491467_54cbc0a866.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/2593406865_ab98490c1f.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/241347391_4fcd4639f4.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/3249062399_0dafe5e4f5.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/2689491604_d8760f57b4.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/3473264983_67917a931f.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/418667611_b9995000f4.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/2567812221_30fb64f5e9.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/3025513877_1a6160070d.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/3080891382_edf83dde18.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/72218201_e0e9c7d65b.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/3694064560_467683205b.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/823675317_b5fbdb17b3.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/3296584432_bef3c965a3.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/2244613488_4d1f9edb33.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/2913818905_8e4d9aa82a.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/3382679230_baef3d1eaa.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/246901891_4c4ea49c3a.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/3497069793_2d4baf5b4b.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/661546153_9d30db6984.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/61209225_8512e1dad5.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/2761599088_8b39cc5f41.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/2322601965_748d59dc57.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/2839932205_3c9c27cd99.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/3405759441_fb31c80240.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/2782850287_1408f7ec43.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/3406409018_03de95181e.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/3273625566_2454f1556b.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/3638783120_f600ceb19d.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/799431781_65dc312afc.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/2228022180_9597b2a458.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/3618932839_acd7d2c2ea.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/2443229844_277cded27d.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/3441531010_8eebbb507e.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/140430106_2978fda105.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/2394763838_99d1435b85.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/3703960010_1e4c922a25.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/2930622766_fa8f84deb1.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/3182258223_5b9c8a8c55.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/3050606344_af711c726c.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/3592968286_b63c81bcd2.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/1772859261_236c09b861.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/1810651611_35aae644fb.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/3232470286_903a61ea16.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/237953705_cfe6999307.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/3431860810_44277cd360.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/3608849440_e7d2bed29f.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/2199793371_343809ff70.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/3570800810_978c993133.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/318667317_108c402140.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/2208631481_3e4a5675e1.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/639865690_d66d480879.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/3504881781_6a842e043b.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/2635938723_11b85e6763.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/2226587791_66e29dd01d.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/963730324_0638534227.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/3223055565_68973f5d20.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/2194286203_5dc620006a.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/166433861_70b66cd381.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/2308256827_3c0a7d514d.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/2976684095_ce7ccfd423.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/3292277400_f95cdd13d1.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/3457045393_2bbbb4e941.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/3356369156_074750c6cc.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/2495394666_2ef6c37519.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/470373679_98dceb19e7.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/2512876666_9da03f9589.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/102351840_323e3de834.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/3639845565_be547c38ba.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/3016606751_0e8be20abd.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/2076906555_c20dc082db.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/2698197294_ccd9327ef6.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/3104400277_1524e4f758.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/3225296260_2ee72b4917.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/2642474867_4e6346f809.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/1770036088_08abe4f6e9.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/3657016761_d553e514d9.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/3551003620_0b02d76f65.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/2751466788_4fab701cc3.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/3484019369_354e0b88c0.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/3726590391_bc6e729bb6.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/1420060020_7a6984e2ea.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/3186073578_6e115f45f5.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/2485467050_1d5e2696d4.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/2873445888_8764699246.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/482088914_e6ea4501e9.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/3134586018_ae03ba20a0.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/3515665835_22e6fb1193.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/2642475077_69d19deb74.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/2929506802_5432054d77.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/3336361161_c06cdd160e.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/2942311160_a154104c62.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/3119913014_688d4997d7.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/1620397000_3883e3ecd3.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/3472540184_b0420b921a.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/2895403073_906768cafa.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/3320209694_db579cb607.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/2855417531_521bf47b50.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/3147913471_322ea231d9.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/3256043809_47258e0b3e.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/937559727_ae2613cee5.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/3273969811_42e9fa8f63.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/1511807116_41c3645e8c.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/3212465975_b657f40eed.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/2576878141_87f25a10f0.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/2180480870_dcaf5ac0df.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/3282434895_1c1efc1475.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/3027399066_ca85495775.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/3458379941_657182bb09.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/1491192153_7c395991e5.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/3370308329_7f2de5bb58.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/3544673666_ffc7483c96.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/3119887967_271a097464.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/2727051596_be65bfb3d3.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/2339140905_9f625f140a.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/976392326_082dafc3c5.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/938162709_21443d352f.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/536828916_b763b82949.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/109202756_b97fcdc62c.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/173020287_230bfc4ffc.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/262446581_06ef7d9445.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/3116769029_f5a76f04ba.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/2098418613_85a0c9afea.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/2493469969_11b6190615.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/292887910_f34ac101c8.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/2830755303_2b5444ab4c.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/2553550034_5901aa9d6c.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/3149919755_f9272b10b3.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/3556037801_3992ce6826.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/391723162_3bdeb7ea33.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/2521213787_ca9b5a1758.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/249394748_2e4acfbbb5.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/3113682377_14fc7b62b0.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/3711664623_ef87105ea7.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/479807833_85eed6899c.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/1386251841_5f384a0fea.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/2196050115_e236d91f52.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/3386060324_b98fdfa449.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/2717686269_80c4b5ac9e.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/3364160101_c5e6c52b25.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/369186134_5eef374112.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/369047365_35476becc9.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/2379150102_157d718d1d.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/2268601066_b018b124fd.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/2836808985_b26e4ca09e.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/3183777589_460a4f445b.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/3555573680_41c1540a86.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/3454754632_977c1523be.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/1865794069_6e3a1e57bb.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/2731171552_4a808c7d5a.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/3474999131_788cbf253f.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/2555622234_3e531e4014.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/3631474374_e40764d153.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/1296770308_3db2022f5a.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/2517082705_93bc9f73ec.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/3549673305_4dfd44e04a.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/3603116579_4a28a932e2.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/2913965136_2d00136697.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/2986716822_e220754d32.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/707972553_36816e53a2.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/2508313118_524e93d48c.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/1446933195_8fe9725d62.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/958326692_6210150354.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/426065353_e9a604a01f.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/3640348910_fcd627ec66.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/2636876892_9353521a1c.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/2976946039_fb9147908d.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/3437034427_6df5e9fbf9.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/2689001252_e0016c89f0.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/2687328779_b4356dab16.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/2338627102_6708a9b4fd.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/2194495372_bdac7d9e71.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/485245061_5a5de43e20.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/3439331800_e71e1d808f.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/2466171114_3fa51415a7.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/3256272547_5ae6c66293.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/381239475_044cbffa2b.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/113678030_87a6a6e42e.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/3476381830_3751dd9339.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/1434005938_ad75c8598c.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/3040033126_9f4b88261b.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/3214885227_2be09e7cfb.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/3647446816_bd4383c828.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/3690883532_d883f34617.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/3691729694_2b97f14c1e.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/3436259762_43709321ff.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/581419370_30485f3580.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/1333888922_26f15c18c3.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/3655964639_21e76383d0.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/3254662117_b2e7dede6e.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/2633082074_32c85f532c.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/3189307452_aebc12380b.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/308307853_5a51fbdecc.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/3712923460_1b20ebb131.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/382701159_f98c1988cd.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/2991994607_06f24ec7a6.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/3458434150_2b0d619244.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/3330680118_4e541889c1.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/1273001772_1585562051.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/3153067758_53f003b1df.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/3351418768_596ef7fd6f.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/1448511770_1a4a9c453b.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/2707873672_15e6b5d54b.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/2728276857_3f83757ef2.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/2865376471_43c5e6b941.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/1432342377_3e41603f26.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/3347666612_659e6e2207.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/1153704539_542f7aa3a5.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/2714699748_c9270dd5aa.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/2705793985_007cc703fb.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/3306464579_1b16a0caf2.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/3110614694_fecc23ca65.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/2939197393_93dc64c4bb.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/3258396041_69717247f7.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/2250555512_71670078f5.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/2977246776_b14be8290d.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/2273028514_d7b584f73d.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/3348191949_b0b925e5f1.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/2314722788_6262c3aa40.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/2713897716_c8cd610360.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/2718495608_d8533e3ac5.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/1402843760_d30f1dbf0f.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/3300679815_2c6c2301cb.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/3523819210_99782628fc.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/1397887419_e798697b93.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/2830880811_d7f66dd2cf.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/562928217_21f967a807.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/2909955251_4b326a46a7.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/95151149_5ca6747df6.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/2636514498_01fcc5f501.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/2466420387_86fe77c966.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/3139389284_f01bd4c236.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/1453366750_6e8cf601bf.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/78984436_ad96eaa802.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/3134341610_3c55e373a7.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/343218198_1ca90e0734.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/2594042571_2e4666507e.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/247652942_29ede19352.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/2896483502_6f807bae9e.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/2916586390_664f0139ea.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/3073579130_7c95d16a7f.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/3225880532_c8d5d1d798.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/3736786640_70df13be2c.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/2246717855_c0c08fe5d2.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/2662890367_382eaf83bd.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/2519594430_551225e5bd.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/502671104_b2114246c7.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/3339586622_a7676b30e1.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/222369445_5b6af347dd.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/1481062342_d9e34366c4.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/820169182_f5e78d7d19.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/2615623392_ab2b9759ae.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/1321949151_77b77b4617.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/3506560025_8d0f4f9ac4.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/2848977044_446a31d86e.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/461019788_bc0993dabd.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/2885111681_dc328ecfff.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/3143574389_8a4048fbe2.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/2476214153_99a3998509.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/460781612_6815c74d37.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/2891162278_fbf96be4f4.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/3687995245_624b54090d.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/1247181182_35cabd76f3.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/2525666287_638ab5e784.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/3567214106_6ece483f8b.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/3293751136_b0ce285dc3.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/2420546021_4a59790da6.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/3371887001_44ab0c2f17.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/2963672852_c28043bb2c.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/3155987659_b9ea318dd3.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/3084011028_d1e2c40d7d.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/2229179070_dc8ea8582e.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/3402081035_a54cfab1d9.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/3254817653_632e840423.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/441921713_1cafc7d7d2.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/3569406219_f37ebf7b92.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/3088399255_1bd9a6aa04.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/2879241506_b421536330.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/2192475933_d779bf42eb.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/3380407617_07b53cbcce.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/3538686658_30afc75f02.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/2068465241_3bcabacfd7.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/2982928615_06db40f4cd.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/3430287726_94a1825bbf.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/2222186636_85e03e0b75.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/2863848437_f2592ab42d.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/3288173388_03bc2a844d.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/2944952557_8484f0da8f.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/3513265399_a32e8cfd18.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/3582689770_e57ab56671.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/2853205396_4fbe8d7a73.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/3230132205_dccfafa5ee.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/3413973568_6630e5cdac.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/1303548017_47de590273.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/3618504267_d7eaa495d0.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/2912476706_9a0dbd3a67.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/561179890_af8e31cb2e.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/3728164558_52729baefa.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/2662262499_3cdf49cedd.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/3464871350_3f2d624a9c.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/3437107047_715c60e9c8.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/531197115_2be4d5034b.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/241345981_1ef4f8109c.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/1466479163_439db855af.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/2181724497_dbb7fcb0a9.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/2943079526_e9033a6556.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/1236964638_1808784a3c.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/3088922727_4bdf2ccc94.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/2442243868_abe8f74fb4.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/2281768510_9cc5728c55.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/236095034_c983bdfbbf.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/3232252882_05db7c2216.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/2708582445_5e5999b956.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/495033548_bd320405d8.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/2651915425_7a58e862e9.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/3558438174_d8f41438a4.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/2744690159_fe2c89e55b.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/2579899436_5086a33c7a.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/3048211972_db71d104c2.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/521658170_a837af87e9.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/3522349685_f046f0e250.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/2441313372_6a1d59582b.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/3215081286_d55541aa6b.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/3528902357_be2357a906.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/501520507_c86f805ab8.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/3193335577_9bdbaf9f70.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/2610447973_89227ff978.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/3174453534_fcc927c647.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/3461049169_e068ae4f25.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/2053733930_e245615ad4.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/2615811117_42b1838205.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/3500115252_9404c066a8.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/3517023411_a8fbd15230.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/2427490900_5b7a8874b9.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/2086534745_1e4ab80078.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/3467219837_7d62213dec.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/3516825206_5750824874.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/3184891327_8785194e3c.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/2081615901_13092cac56.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/3328495660_ed0e3f29cf.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/2059842472_f4fb61ea08.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/460478198_83039f2593.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/3185787277_b412d7f5b7.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/2752084369_52e7867da7.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/3271385712_ffd34f2de5.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/2183967273_d182e18cf6.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/2868668723_0741222b23.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/1801063894_60bce29e19.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/189721896_1ffe76d89e.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/186890601_8a6b0f1769.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/2156726763_034ecd2e39.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/2662845514_8620aaee96.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/2596475173_58f11fc583.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/244368383_e90b6b2f20.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/3717809376_f97611ab84.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/1075881101_d55c46bece.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/2344699642_4fae2f4e07.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/1100214449_d10861e633.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/3156406419_38fbd52007.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/2897832422_0cbdb1421e.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/2066048248_f53f5ef5e2.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/492341908_1ef53be265.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/3523920786_0eb63993fd.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/2496399593_a24954a5ca.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/2208055895_37cd8e1edf.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/2107838729_a527e434bd.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/2271671533_7538ccd556.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/111537217_082a4ba060.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/260162669_c79a900afb.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/2243904502_2d265fed80.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/217838128_1f0a84ddc1.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/3421129418_088af794f7.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/3235746553_a40416c00e.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/2089426086_7acc98a3a8.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/191003284_1025b0fb7d.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/140377584_12bdbdf2f8.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/2942798367_022df04b49.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/3559781965_d4ec00e506.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/2602415701_7674eb19e4.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/2596514158_c516e57974.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/3209523192_05a4cef844.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/391579205_c8373b5411.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/364213568_7f83e7d144.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/3357937209_cf4a9512ac.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/2937942758_712be5c610.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/757046028_ff5999f91b.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/537758332_8beb9cf522.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/3537474810_cf676b3259.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/2573625591_70291c894a.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/222878446_32c6fc4bc9.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/2877159456_ea4a46b0d2.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/857914283_270d7d1c87.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/3393446245_37dd3f3b59.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/1142283988_6b227c5231.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/2943023421_e297f05e11.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/3283368342_b96d45210e.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/3514184232_b336414040.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/2194494220_bb2178832c.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/3350260112_fcb47ff6b2.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/551403320_dfdcf9fc3b.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/2732625904_4fbb653434.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/2223382277_9efa58ec45.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/2616561200_ea079f285a.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/534875358_6ea30d3091.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/314904143_5a216a192b.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/414568315_5adcfc23c0.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/3392851587_a638ff25e2.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/2325258180_6217dd17eb.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/3656906086_7034f69ab6.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/3293642024_e136b74a55.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/280932151_ae14a67be5.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/426920445_d07d1fd0f7.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/3486538055_bcf4d3dfda.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/2591110592_ef5f54f91c.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/2574194729_1f099647ee.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/2588927489_f4da2f11ec.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/2665264979_df9c284bf8.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/979201222_75b6456d34.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/3043266735_904dda6ded.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/1526325728_74eb4153d8.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/2789688929_9424fceed1.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/3029472296_d429b1586c.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/3399618896_9ef60cd32c.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/3388094307_5a83be64a5.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/2877424957_9beb1dc49a.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/3474330484_a01d8af624.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/447111935_5af98563e3.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/452345346_afe1248586.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/287999021_998c2eeb91.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/1998457059_c9ac9a1e1a.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/2864340145_d28b842faf.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/3218861747_5c5c547b66.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/3171035252_dba286ae5c.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/2657484970_610e18144f.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/3313620862_0c65c645f5.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/172092461_a9a9762e13.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/3331009729_d3b14738e6.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/293327462_20dee0de56.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/2947274789_a1a35b33c3.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/3516653997_98ec551a67.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/3174726084_c108de0a64.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/837919879_94e3dacd83.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/3703035378_c6034cac51.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/323657582_b6b6d8f7bd.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/1433577867_39a1510c43.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/511749704_3037806cb1.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/3103185190_eb8729c166.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/3154709407_9b0778cbeb.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/2967549094_d32422eb01.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/3225058391_a12d38d911.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/3590647207_2d4ec3f52c.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/2665586311_9a5f4e3fbe.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/247618600_239eeac405.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/2339573065_91f1e3be60.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/3527926597_45af299eee.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/2255332561_3375897ff0.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/3601491447_a338875b51.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/512031915_0dd03dcdf9.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/2393971707_bce01ae754.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/300314926_0b2e4b64f5.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/530454257_66d58b49ee.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/3709030554_02301229ea.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/2675190069_d5c3b2c876.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/3335547029_74d620fa6c.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/2878705136_609dfbf318.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/3759230208_1c2a492b12.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/3375549004_beee810e60.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/1149179852_acad4d7300.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/2880874989_a33b632924.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/1160034462_16b38174fe.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/2526041608_a9775ab8d7.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/336551615_a01418bc53.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/3523874798_9ba2fa46e3.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/3665179773_dd217416fc.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/3726168984_1fa2c8965b.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/3177298173_78cea31d64.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/2426828433_ce894d1c54.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/3679341667_936769fd0c.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/2787868417_810985234d.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/2206600240_f65df56a09.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/2247138288_7355861203.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/804087017_330bcc8c56.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/3436074878_21515a6706.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/1923476156_e20976b32d.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/2453971388_76616b6a82.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/485357535_b45ba5b6da.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/2768021570_46bc6325e3.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/3549011001_26cace3646.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/279728508_6bd7281f3c.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/3006217970_90b42e6b27.jpg
# ...
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/3530502404_f8c3a3f61c.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/2892395757_0a1b0eedd2.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/3519942322_b37d088aae.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/2293424366_7b5fcd2398.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/3726700898_c50494b8bd.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/1499495021_d295ce577c.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/274313927_404d0e94ab.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/1383840121_c092110917.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/3621652774_fd9634bd5b.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/3102204862_f1d220230b.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/2495931537_9b8d4474b6.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/2795352290_9209b214f3.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/142802798_962a4ec5ce.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/3475581086_a533567561.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/543007912_23fc735b99.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/19212715_20476497a3.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/3259160693_067ec7ebc3.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/3062173277_bfb5ef4c45.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/1252787177_4b08625897.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/3421480658_b3518b6819.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/637342973_89f6fac1f7.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/241346105_c1c860db0d.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/3431121650_056db85987.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/1937262236_cbf5bfa101.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/503794526_603a7954d3.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/2038662925_f4fa8c2534.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/2695085862_2ed62df354.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/2396100671_3a9d67f03d.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/146098876_0d99d7fb98.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/3211556865_d1d9becf69.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/2333584535_1eaf9baf3e.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/2878578240_caf64c3b19.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/3604314527_5077cd9d43.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/766346887_a9a9d0637a.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/3197891333_b1b0fd1702.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/1969573381_5ecfae4c80.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/3169777863_d745865784.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/2856456013_335297f587.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/2287023569_fd7a9c60b8.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/3174156702_95a1cda2d9.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/2363419943_717e6b119d.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/1244485675_822e6efe60.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/2909609550_070eea49b5.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/1389323170_d1c81d6b51.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/3021318991_fa28e3bca7.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/310213587_778fe8fb5b.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/2466171100_5e60cfcc11.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/693450725_8ad72389e6.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/3195969533_98f5de0fab.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/3359089834_263e529c71.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/3606942887_1159d92548.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/3401437960_7da856e004.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/299676757_571ee47280.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/2120571547_05cd56de85.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/3138562460_44227a35cf.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/145721498_a27d2db576.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/3228960484_9aab98b91a.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/3217910740_d1d61c08ab.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/3277824093_299cbb3138.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/2584020755_14e2b3e8fc.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/2570559405_dc93007f76.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/3688839836_ba5e4c24fc.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/295258727_eaf75e0887.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/3397220683_4aca010f86.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/3419197575_aa5b84a9f0.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/3329793486_afc16663cc.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/429205889_ff5a006311.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/299178969_5ca1de8e40.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/3029928396_99ac250788.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/1427391496_ea512cbe7f.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/2938747424_64e64784f0.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/1389264266_8170bc1c54.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/549887636_0ea5ae4739.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/2061144717_5b3a1864f0.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/642987597_03b21a1437.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/298920219_9a3f80acc5.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/260520547_944f9f4c91.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/3208074567_ac44aeb3f3.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/539493431_744eb1abaa.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/875731481_a5a0a09934.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/3710353645_8fbfaa4175.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/3455920874_6fbec43194.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/2303426046_09cfd7bc4e.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/3673878924_506c9d767b.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/2431120202_b24fe2333a.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/3585117340_73e96b6173.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/2684489465_32ba1d0344.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/2125626631_a4b63af97e.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/2496236371_61dec88113.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/1289142574_2bd6a082dd.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/566446626_9793890f95.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/3457572788_e1fe4f6480.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/1358892595_7a37c45788.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/3106782647_b078830a9e.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/3101796900_59c15e0edc.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/3222250187_ef610f267e.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/743571049_68080e8751.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/3415003392_139c0f3586.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/254295381_d98fa049f4.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/3331190056_09f4ca9fd2.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/1490213660_9ea45550cf.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/3181328245_7c04ce1691.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/1417031097_ab656bc4bd.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/3276895962_c053263d01.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/3692836015_d11180727b.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/3286406057_a1668655af.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/350176185_b8c5591e36.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/3491607076_922ec561d9.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/2279980395_989d48ae72.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/3437781040_82b06facb3.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/1387443857_602ab6f9bf.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/1248357227_2b4175fc39.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/3453284877_8866189055.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/3244470342_c08f6bb17e.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/330849796_c575c3108a.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/2687229880_97cfd8148e.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/2274602044_b3d55df235.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/3016726158_4d15b83b06.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/2448270671_5e0e391a80.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/2188688248_f57a28a5a7.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/3430100177_5864bf1e73.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/3374223949_90776ba934.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/2261962622_e9318a95eb.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/3208553539_2bf6c6d162.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/2647394564_4843800cff.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/698107542_3aa0ba78b4.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/437404867_209625774d.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/2830309113_c79d7be554.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/3724113279_99b6e5bf41.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/3681324243_b69fa90842.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/236518934_c62a133077.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/3038045802_93f2cd5fbc.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/3234719720_5bb2fc5ffa.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/3042483842_beb23828b9.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/2699426519_228719b1db.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/240583223_e26e17ee96.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/2128119486_4407061c40.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/2444741900_5cb3ef3e1d.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/1807169176_7f5226bf5a.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/247691240_3881777ab8.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/525968880_82623392d1.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/1406010299_5755339f08.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/3530504007_3272c57e21.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/3694219419_a7a83d4886.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/2256138896_3e24b0b28d.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/159712188_d530dd478c.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/3724150944_fc62e8d5e0.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/1418266617_b32143275b.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/2698614194_b4e6e11dff.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/759015118_4bd3617e60.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/1763020597_d4cc8f0f8a.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/1581822598_0ae23074f1.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/406642021_9ec852eccf.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/899810584_61e1578d3f.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/2501742763_b2cb322087.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/2934837034_a8ca5b1f50.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/3677693858_62f2f3163f.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/2918880895_e61f74f2f0.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/3175849727_bf30b892cb.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/3704995657_e2e114083d.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/3339140382_2e49bc324a.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/2660480624_45f88b3022.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/652542470_60e858da64.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/3636543173_15f56515e5.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/3125158798_0743dae56e.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/3459492423_c881f12c9f.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/3500136982_bf7a85531e.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/412101267_7257e6d8c0.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/3354883962_170d19bfe4.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/3549277110_24d4064ccd.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/3255732353_fbc487aefc.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/3322443827_a04a94bb91.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/1579198375_84b18e003a.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/3330019493_fd36fbc2ea.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/3335370208_460fc19bfa.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/2774581025_81a3074e2e.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/3569420080_72fbe84751.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/533713007_bf9f3e25b4.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/2266142543_b2de18c081.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/3074617663_2f2634081d.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/3249014584_21dd9ddd9d.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/3294830188_e46bd9b93c.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/3272002857_ace031f564.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/3346040664_5b584e6133.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/3512033861_a357bb58b6.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/498444334_a680d318a1.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/2473791980_805c819bd4.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/2993167197_e5d0a73530.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/3364258732_9942c557e5.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/3081363964_d404eccae8.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/3684562647_28dc325522.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/1287073593_f3d2a62455.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/2543679402_9359e1ee4e.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/608257195_6ec6f48e37.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/3374384485_751f719be4.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/3189941492_a3f4347b1a.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/3674565156_14d3b41450.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/272283076_2d4aa1d5cf.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/281419391_522557ce27.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/590445887_4d4fa43923.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/502115726_927dd684d3.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/3025438110_40af7e6a80.jpg
# /kaggle/input/flickr8kimagescaptions/flickr8k/images/2623982903_58ec7c5026.jpg

# %%
# !pip install torchviz
# Out:
# Requirement already satisfied: torchviz in /opt/conda/lib/python3.10/site-packages (0.0.3)
# Requirement already satisfied: torch in /opt/conda/lib/python3.10/site-packages (from torchviz) (2.4.0)
# Requirement already satisfied: graphviz in /opt/conda/lib/python3.10/site-packages (from torchviz) (0.20.3)
# Requirement already satisfied: filelock in /opt/conda/lib/python3.10/site-packages (from torch->torchviz) (3.15.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in /opt/conda/lib/python3.10/site-packages (from torch->torchviz) (4.12.2)
# Requirement already satisfied: sympy in /opt/conda/lib/python3.10/site-packages (from torch->torchviz) (1.13.3)
# Requirement already satisfied: networkx in /opt/conda/lib/python3.10/site-packages (from torch->torchviz) (3.3)
# Requirement already satisfied: jinja2 in /opt/conda/lib/python3.10/site-packages (from torch->torchviz) (3.1.4)
# Requirement already satisfied: fsspec in /opt/conda/lib/python3.10/site-packages (from torch->torchviz) (2024.6.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/conda/lib/python3.10/site-packages (from jinja2->torch->torchviz) (2.1.5)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /opt/conda/lib/python3.10/site-packages (from sympy->torch->torchviz) (1.3.0)

# %%
# !pip install --upgrade nltk
# Out:
# Requirement already satisfied: nltk in /opt/conda/lib/python3.10/site-packages (3.9.1)
# Requirement already satisfied: click in /opt/conda/lib/python3.10/site-packages (from nltk) (8.1.7)
# Requirement already satisfied: joblib in /opt/conda/lib/python3.10/site-packages (from nltk) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in /opt/conda/lib/python3.10/site-packages (from nltk) (2024.5.15)
# Requirement already satisfied: tqdm in /opt/conda/lib/python3.10/site-packages (from nltk) (4.66.4)

# %%
# !pip install torchsummary
# Out:
# Requirement already satisfied: torchsummary in /opt/conda/lib/python3.10/site-packages (1.5.1)

# %%
# !pip install tensorboard
# Out:
# Requirement already satisfied: tensorboard in /opt/conda/lib/python3.10/site-packages (2.16.2)
# Requirement already satisfied: absl-py>=0.4 in /opt/conda/lib/python3.10/site-packages (from tensorboard) (1.4.0)
# Requirement already satisfied: grpcio>=1.48.2 in /opt/conda/lib/python3.10/site-packages (from tensorboard) (1.62.2)
# Requirement already satisfied: markdown>=2.6.8 in /opt/conda/lib/python3.10/site-packages (from tensorboard) (3.6)
# Requirement already satisfied: numpy>=1.12.0 in /opt/conda/lib/python3.10/site-packages (from tensorboard) (1.26.4)
# Requirement already satisfied: protobuf!=4.24.0,>=3.19.6 in /opt/conda/lib/python3.10/site-packages (from tensorboard) (3.20.3)
# Requirement already satisfied: setuptools>=41.0.0 in /opt/conda/lib/python3.10/site-packages (from tensorboard) (70.0.0)
# Requirement already satisfied: six>1.9 in /opt/conda/lib/python3.10/site-packages (from tensorboard) (1.16.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /opt/conda/lib/python3.10/site-packages (from tensorboard) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /opt/conda/lib/python3.10/site-packages (from tensorboard) (3.1.3)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /opt/conda/lib/python3.10/site-packages (from werkzeug>=1.0.1->tensorboard) (2.1.5)

# %%
import os
import re
import pandas as pd
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
from torch.optim.lr_scheduler import StepLR
from torchvision.transforms import transforms
from torchvision.models import resnet50,ResNet50_Weights
from torch.utils.data import Dataset,DataLoader
import matplotlib.pyplot as plt
from collections import defaultdict,Counter
from PIL import Image
from nltk.translate.bleu_score import corpus_bleu, SmoothingFunction
from nltk.translate.meteor_score import meteor_score
from sklearn.model_selection import train_test_split
from torch.optim.lr_scheduler import StepLR
import torch.optim as optim
import random
from textwrap import wrap

# %%
# to make sure the results are reproducible
torch.manual_seed(0)
random.seed(42)

# %%
df=pd.read_csv("/kaggle/input/flickr8kimagescaptions/flickr8k/captions.txt")
df
# Out:
#                            image  \
# 0      1000268201_693b08cb0e.jpg
# 1      1000268201_693b08cb0e.jpg
# 2      1000268201_693b08cb0e.jpg
# 3      1000268201_693b08cb0e.jpg
# 4      1000268201_693b08cb0e.jpg
# ...                          ...
# 40450   997722733_0cb5439472.jpg
# 40451   997722733_0cb5439472.jpg
# 40452   997722733_0cb5439472.jpg
# 40453   997722733_0cb5439472.jpg
# 40454   997722733_0cb5439472.jpg
#
#                                                  caption
# 0      A child in a pink dress is climbing up a set o...
# 1                  A girl going into a wooden building .
# 2       A little girl climbing into a wooden playhouse .
# 3      A little girl climbing the stairs to her playh...
# 4      A little girl in a pink dress going into a woo...
# ...                                                  ...
# 40450           A man in a pink shirt climbs a rock face
# 40451           A man is rock climbing high in the air .
# 40452  A person in a red shirt climbing up a rock fac...
# 40453                    A rock climber in a red shirt .
# 40454  A rock climber practices on a rock climbing wa...
#
# [40455 rows x 2 columns]

# %%
def read_image(path,img_size=224):
      transform = transforms.Compose([
        transforms.Resize((img_size, img_size)),
        transforms.ToTensor()])
      img = Image.open(path).convert('RGB')
      img = transform(img)
      return img.permute(1, 2, 0).numpy()

# %%
def display_image(temp_df):
    temp_df=temp_df.reset_index(drop=True)
    plt.figure(figsize=(20, 20))
    n = 0
    for i in range(5):  # Display 15 images
        n += 1
        plt.subplot(5, 5, n)
        plt.subplots_adjust(hspace=0.7, wspace=0.3)
        
        # Load and display the image
        image_path = f"/kaggle/input/flickr8kimagescaptions/flickr8k/images/{temp_df.image[i]}"
        image = read_image(image_path)
        plt.imshow(image)
        
        # Display the caption
        caption = "\n".join(wrap(temp_df.caption[i], 20))  # Wrap text for better display
        plt.title(caption)
        plt.axis("off")  # Turn off axis
    
    plt.show()

# %%
display_image(df.sample(5))

# %% [markdown]
# # Data Preprocessing

# %%
image_captions = defaultdict(list)
for idx, row in df.iterrows():
    image_captions[row['image']].append(row['caption'])

# %%
def tokenize(text):
    # Convert text to lowercase
    text = text.lower()
    # Use regular expressions to extract words (alphanumeric characters)
    tokens = re.findall(r'\w+', text)
    return tokens

# %%
tokenize("Sudhanva Is 1111 @ the greatest of all time")
# Out:
# ['sudhanva', 'is', '1111', 'the', 'greatest', 'of', 'all', 'time']

# %%
all_captions = []
for captions in image_captions.values():
    all_captions.extend(captions)

# %%
all_words = []
for caption in all_captions:
    tokens = tokenize(caption)
    all_words.extend(tokens)

# %%
all_words[0:10]
# Out:
# ['a', 'child', 'in', 'a', 'pink', 'dress', 'is', 'climbing', 'up', 'a']

# %%
all_captions[0:10]
# Out:
# ['A child in a pink dress is climbing up a set of stairs in an entry way .',
#  'A girl going into a wooden building .',
#  'A little girl climbing into a wooden playhouse .',
#  'A little girl climbing the stairs to her playhouse .',
#  'A little girl in a pink dress going into a wooden cabin .',
#  'A black dog and a spotted dog are fighting',
#  'A black dog and a tri-colored dog playing with each other on the road .',
#  'A black dog and a white dog with brown spots are staring at each other in the street .',
#  'Two dogs of different breeds looking at each other on the road .',
#  'Two dogs on pavement moving toward each other .']

# %%
word_counts = Counter(all_words)
word_counts["girl"]
# Out:
# 3328

# %%
special_tokens = ['<pad>', '<start>', '<end>', '<unk>']
# Create mappings from words to indices and vice versa
word2idx = {token: idx for idx, token in enumerate(special_tokens)}
idx2word = {idx: token for idx, token in enumerate(special_tokens)}

# %%
word2idx
# Out:
# {'<pad>': 0, '<start>': 1, '<end>': 2, '<unk>': 3}

# %%
idx2word
# Out:
# {0: '<pad>', 1: '<start>', 2: '<end>', 3: '<unk>'}

# %%
vocab_size = 10000 # we have set it as the max limit inluding the special tokens
most_common = word_counts.most_common(vocab_size - len(special_tokens))

# %%
start_idx=1

# %%
most_common[0:10]
# Out:
# [('a', 62992),
#  ('in', 18986),
#  ('the', 18419),
#  ('on', 10745),
#  ('is', 9345),
#  ('and', 8862),
#  ('dog', 8138),
#  ('with', 7765),
#  ('man', 7274),
#  ('of', 6723)]

# %%
len(most_common)
# Out:
# 8488

# %%
# we are starting after the length of start tokens
for idx, (word, _) in enumerate(most_common, start=len(special_tokens)):
    word2idx[word] = idx
    idx2word[idx] = word

# %%
word2idx["a"]
# Out:
# 4

# %%
captions_seqs = {}
max_length = 0  # Keep track of the maximum caption length
for img_name, captions in image_captions.items():
    seqs = []
    for caption in captions:
        # Tokenize the caption and add <start> and <end> tokens
        tokens = ['<start>'] + tokenize(caption) + ['<end>']
        # Convert tokens to indices, use <unk> index if word not in vocabulary
        seq = [word2idx.get(token, word2idx['<unk>']) for token in tokens]
        seqs.append(seq)
        # Update the maximum caption length
        max_length = max(max_length, len(seq))
    captions_seqs[img_name] = seqs

# %%
# so now we have a dictionary with image as key and indices of words in captions as keys so the values is a list of lists
captions_seqs["1000268201_693b08cb0e.jpg"]
# Out:
# [[1, 4, 44, 5, 4, 91, 173, 8, 120, 52, 4, 394, 13, 395, 5, 29, 5156, 671, 2],
#  [1, 4, 20, 317, 65, 4, 197, 118, 2],
#  [1, 4, 41, 20, 120, 65, 4, 197, 2438, 2],
#  [1, 4, 41, 20, 120, 6, 395, 21, 61, 2438, 2],
#  [1, 4, 41, 20, 5, 4, 91, 173, 317, 65, 4, 197, 2982, 2]]

# %% [markdown]
# # Image Transformation for Preprocessing

# %%
transform = transforms.Compose([
    transforms.Resize((256, 256)),
    transforms.RandomCrop(224),
    transforms.RandomHorizontalFlip(),  # Data augmentation
    transforms.ToTensor(),
    transforms.Normalize((0.485, 0.456, 0.406),  # mean
                         (0.229, 0.224, 0.225))  # std
])

# %% [markdown]
# # Dataloader setup

# %%
class Flickr8kDataset(Dataset):
    def __init__(self, image_dir, image_ids, captions_seqs, transform=None):
        """
        Args:
            image_dir (string): Directory with all the images.
            image_ids (list): List of image filenames.
            captions_seqs (dict): Dictionary mapping image filenames to sequences of word indices.
            transform (callable, optional): Optional transform to be applied on an image.
        """
        self.image_dir = image_dir
        self.transform = transform
        self.images = []
        self.captions = []
        # Prepare the list of image and caption pairs
        for img_id in image_ids:
            captions = captions_seqs[img_id]
            for caption_seq in captions:
                self.images.append(img_id)
                self.captions.append(caption_seq)
    def __len__(self):
        # Return the total number of samples
        return len(self.images)
    def __getitem__(self, idx):
        # Get the image filename and caption sequence at the given index
        img_id = self.images[idx]
        caption_seq = self.captions[idx]
        # Load the image from the directory
        img_path = os.path.join(self.image_dir, img_id)
        image = Image.open(img_path).convert('RGB')

        # Apply the transformations if any
        if self.transform:
            image = self.transform(image)

        # Convert the caption sequence to a tensor
        caption_seq = torch.tensor(caption_seq)
        return image, caption_seq

# %%
def collate_fn(data):
    """
    Creates mini-batch tensors from the list of tuples (image, caption).
    We sort the captions by length to use pack_padded_sequence.
    """
    # Sort data by caption length in descending order
    data.sort(key=lambda x: len(x[1]), reverse=True)
    images, captions = zip(*data)

    # Stack images into a tensor of shape (batch_size, 3, H, W)
    images = torch.stack(images, 0)
    # Get the lengths of each caption
    lengths = [len(cap) for cap in captions]
    # Create a tensor to hold the padded captions
    targets = torch.zeros(len(captions), max(lengths)).long()
    for i, cap in enumerate(captions):
        end = lengths[i]
        # Copy the caption into the targets tensor
        targets[i, :end] = cap[:end]

    return images, targets, lengths

# %%
image_dir = '/kaggle/input/flickr8kimagescaptions/flickr8k/images'
image_names = list(image_captions.keys())

# %%
train_images, temp_images = train_test_split(image_names, test_size=0.3, random_state=42)

# %%
val_images, test_images = train_test_split(temp_images, test_size=0.5, random_state=42)

# %%
train_dataset = Flickr8kDataset(image_dir, train_images, captions_seqs, transform)
val_dataset   = Flickr8kDataset(image_dir, val_images, captions_seqs, transform)
test_dataset  = Flickr8kDataset(image_dir, test_images, captions_seqs, transform)

# %%
batch_size = 32  # Define the batch size

train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True, num_workers=2, collate_fn=collate_fn)
val_loader   = DataLoader(val_dataset, batch_size=batch_size, shuffle=False, num_workers=2, collate_fn=collate_fn)
test_loader  = DataLoader(test_dataset, batch_size=batch_size, shuffle=False, num_workers=2, collate_fn=collate_fn)

# %% [markdown]
# # Model

# %%
# let us define the encoder class
import torchvision.models as models
class EncoderCNN(nn.Module):
    def __init__(self, hidden_size):
        """
        Initialize the Encoder CNN using a pre-trained ResNet with BatchNorm
        
        Args:
            hidden_size (int): Dimension of the output feature vector
        """
        super(EncoderCNN, self).__init__()
        
        # Load pre-trained ResNet model (you can choose different variants like resnet50, resnet101)
        resnet = models.resnet50(pretrained=True)
        
        # Remove the last fully connected layer
        modules = list(resnet.children())[:-1]
        self.resnet = nn.Sequential(*modules)
        
        # Freeze the parameters of the pre-trained ResNet
        for param in self.resnet.parameters():
            param.requires_grad = False
        
        # Add a custom linear layer to map to hidden_size
        self.adaptive_pool = nn.AdaptiveAvgPool2d(1)  # Reduce spatial dimensions to 1x1
        
        # Create a sequential block with linear layer and batch normalization
        self.feature_mapper = nn.Sequential(
            nn.Linear(resnet.fc.in_features, hidden_size),
            nn.BatchNorm1d(hidden_size2)
        )
        
    def forward(self, images):
        """
        Forward pass of the Encoder CNN
        
        Args:
            images (torch.Tensor): Input images of shape (batch_size, 3, height, width)
        
        Returns:
            torch.Tensor: Image features of shape (batch_size, hidden_size)
        """
        # Extract features using the modified ResNet
        with torch.no_grad():
            features = self.resnet(images)
        
        # Apply adaptive pooling to reduce spatial dimensions
        features = self.adaptive_pool(features)
        
        # Flatten the features
        features = features.view(features.size(0), -1)
        
        # Pass through the feature mapper (linear + batch norm)
        image_features = self.feature_mapper(features)
        
        return image_features

# %%
class DecoderRNN(nn.Module):
    def __init__(self, vocab_size, hidden_size, embedding_size, dropout_rate=0.5, max_seq_length=50):
        super(DecoderRNN, self).__init__()
        
        # Word embedding layer with dropout
        self.embedding = nn.Embedding(vocab_size, embedding_size)
        self.embedding_dropout = nn.Dropout(p=dropout_rate)
        
        # LSTM layer
        self.lstm = nn.LSTM(
            input_size=embedding_size, 
            hidden_size=hidden_size, 
            batch_first=True
        )
        
        # Output layer (linear + softmax)
        self.fc = nn.Linear(hidden_size, vocab_size)
        
        # Explicit weight initialization
        self.init_weights()
        
        # Store parameters
        self.hidden_size = hidden_size
        self.vocab_size = vocab_size
        self.max_seq_length = max_seq_length
    
    def init_weights(self):
        """
        Initialize weights using Xavier/Glorot initialization
        """
        # Initialize Embedding layer
        nn.init.xavier_uniform_(self.embedding.weight)
        
        # Initialize LSTM weights
        for name, param in self.lstm.named_parameters():
            if 'weight' in name:
                nn.init.xavier_uniform_(param)
            elif 'bias' in name:
                # Initialize LSTM biases
                # Forget gate bias initialization to 1.0 can help with long-term dependencies
                nn.init.zeros_(param)
                # Set forget gate bias to 1.0
                n = param.size(0)
                start, end = n // 4, n // 2
                param.data[start:end].fill_(1.0)
        
        # Initialize output layer weights
        nn.init.xavier_uniform_(self.fc.weight)
        nn.init.zeros_(self.fc.bias)
    
    def forward(self, image_features, captions):
        """
        Forward pass remains the same as in previous implementation
        """
        # Embed the captions and apply dropout
        embeddings = self.embedding(captions)
        embeddings = self.embedding_dropout(embeddings)
        
        # Prepare initial hidden and cell states
        h0 = image_features.unsqueeze(0)  # (1, batch_size, hidden_size)
        c0 = torch.zeros_like(h0)  # Zero initialize cell state
        
        # Pass embeddings through LSTM
        outputs, _ = self.lstm(embeddings, (h0, c0))
        
        # Pass LSTM outputs through linear layer
        predictions = self.fc(outputs)
        
        return predictions

# Rest of the code remains the same as in the previous implementation

# %% [markdown]
# # Hyperparameters,Loss Function and Optimizers

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(f'Using device: {device}')

# Hyperparameters
num_epochs = 10  # Number of epochs for training
embed_size = 256  # Embedding size
hidden_size = 512  # Hidden size of the LSTM
vocab_size = len(word2idx)  # Vocabulary size
# Out:
# Using device: cuda

# %%
# Define the loss function (ignore padding index)
criterion = nn.CrossEntropyLoss(ignore_index=word2idx['<pad>'])

# Define the optimizer (train both encoder and decoder)
# Use different learning rates for different parameter groups
optimizer = optim.Adam([
    {'params': decoder.parameters()},  # Decoder parameters
    {'params': encoder.feature_mapper.parameters()},  # Encoder feature mapper (linear + batch norm)
], lr=1e-4, weight_decay=1e-4)
# Learning rate scheduler to reduce LR after certain epochs
scheduler = StepLR(optimizer, step_size=5, gamma=0.1)

# %% [markdown]
# # Training

# %%
encoder = EncoderCNN(hidden_size).to(device)
decoder = DecoderRNN(vocab_size,hidden_size,embed_size).to(device)
# Out:
# /opt/conda/lib/python3.10/site-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet50_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet50_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)

# %%
def prepare_image2captions(image_ids, captions_seqs, idx2word):
    """
    Prepare a dictionary mapping image IDs to lists of reference captions (each as a list of tokens).
    """
    image2captions = {}
    for img_id in image_ids:
        seqs = captions_seqs[img_id]
        captions_list = []
        for seq in seqs:
            # Convert word indices to words
            caption = [idx2word.get(idx, '<unk>') for idx in seq]
            # Remove special tokens
            caption = [word for word in caption if word not in ['<start>', '<end>', '<pad>']]
            captions_list.append(caption) 
        image2captions[img_id] = captions_list
    return image2captions

# %%
# Prepare validation and test image-to-captions mappings
val_image2captions = prepare_image2captions(val_images, captions_seqs, idx2word)
test_image2captions = prepare_image2captions(test_images, captions_seqs, idx2word)

# %%
def generate_caption_ids(decoder, features, word2idx, max_length=50):
    """
    Generate a caption for an image given the extracted features.
    """
    sampled_ids = []
    start_idx = word2idx['<start>']
    end_idx = word2idx['<end>']

    # Initialize hidden and cell states (unbatched case)
    hidden_size = features.size(1)
    states = features.unsqueeze(0)  # Shape: [1, hidden_size] -> [num_layers=1, batch_size=1, hidden_size]
    c = torch.zeros_like(states)  # Initialize cell state of same shape

    # Initialize the input with the <start> token
    inputs = torch.tensor([[start_idx]], dtype=torch.long).to(features.device)  # [batch_size=1, seq_len=1]

    for _ in range(max_length):
        # Embed the input token
        input_embedding = decoder.embedding(inputs)  # [batch_size=1, seq_len=1, embed_size]
        
        # Pass through the LSTM
        hiddens, (states, c) = decoder.lstm(input_embedding, (states, c))  # Unbatched, so 2-D states
        
        # Pass through the linear layer to get scores over the vocabulary
        outputs = decoder.fc(hiddens.squeeze(1))  # [batch_size=1, vocab_size]
        
        # Get the most probable word index
        predicted = outputs.argmax(dim=1)  # [batch_size=1]
        sampled_ids.append(predicted.item())

        # If the <end> token is generated, stop
        if predicted.item() == end_idx:
            break

        # Prepare the next input (predicted word)
        inputs = predicted.unsqueeze(1)  # Shape: [batch_size=1, seq_len=1]

    return sampled_ids

# %%
def calculate_bleu_score(encoder, decoder, image_dir, image_ids, image2captions, transform, word2idx, idx2word):
    """
    Calculate the BLEU score for the generated captions against the reference captions.
    """
    encoder.eval()
    decoder.eval()
    references = []
    hypotheses = []
    smoothie = SmoothingFunction().method4  # Smoothing function for BLEU

    with torch.no_grad():
        for img_id in image_ids:
            # Load and preprocess the image
            img_path = os.path.join(image_dir, img_id)
            image = Image.open(img_path).convert('RGB')
            image = transform(image).unsqueeze(0).to(device)
            # Generate caption
            features = encoder(image)
            sampled_ids = generate_caption_ids(decoder, features, word2idx, max_length=50)
            # Convert word indices to words
            sampled_caption = [idx2word.get(word_id, '<unk>') for word_id in sampled_ids]
            # Remove special tokens and lower case
            sampled_caption = [word.lower() for word in sampled_caption if word not in ['<start>', '<end>', '<pad>']]

            # Append hypothesis and references
            hypotheses.append(sampled_caption)
            # References need to be lowercased as well
            ref_captions = [[word.lower() for word in ref] for ref in image2captions[img_id]]
            #ref_captions = image2captions[img_id]
            references.append(ref_captions)
    # Compute BLEU score
    bleu_score = corpus_bleu(references, hypotheses, smoothing_function=smoothie)
    return bleu_score

# %%
def evaluate(encoder, decoder, data_loader):
    """
    Evaluate the model on a given data loader and compute the average loss.
    """
    encoder.eval()
    decoder.eval()
    total_loss = 0
    total_samples = 0

    with torch.no_grad():
        for images, captions, lengths in data_loader:
            images = images.to(device)
            captions = captions.to(device)
            lengths = torch.tensor(lengths)
            adjusted_lengths = lengths - 1  # Adjust lengths for excluding the last token
    # Prepare targets by excluding the <start> token
            targets = nn.utils.rnn.pack_padded_sequence(
                captions[:, 1:], adjusted_lengths, batch_first=True, enforce_sorted=False
            )[0]

            # Forward pass
            features = encoder(images)
            outputs = decoder(features, captions)
            # Pack the outputs
            outputs = nn.utils.rnn.pack_padded_sequence(
                outputs, adjusted_lengths, batch_first=True, enforce_sorted=False
            )[0]

            # Compute loss
            loss = criterion(outputs, targets)
            total_loss += loss.item()
            total_samples += 1

    average_loss = total_loss / total_samples
    return average_loss

# %%
# Lists to store training and validation metrics
train_losses = []
val_losses = []
val_bleu_scores = []

# %%
for epoch in range(num_epochs):
    encoder.train()
    decoder.train()
    total_loss = 0

    for i, (images, captions, lengths) in enumerate(train_loader):
        images = images.to(device)
        captions = captions.to(device)
        lengths = torch.tensor(lengths)
        adjusted_lengths = lengths - 1  # Adjust lengths for excluding the last token

        # Prepare targets by excluding the <start> token
        targets = nn.utils.rnn.pack_padded_sequence(
            captions[:, 1:], adjusted_lengths, batch_first=True, enforce_sorted=False
        )[0]

        # Forward pass
        features = encoder(images)
        outputs = decoder(features, captions)
        # Pack the outputs
        outputs = nn.utils.rnn.pack_padded_sequence(
            outputs, adjusted_lengths, batch_first=True, enforce_sorted=False
        )[0]

        # Compute loss
        loss = criterion(outputs, targets)

        # Backward pass and optimization
        optimizer.zero_grad()
        loss.backward()

        # Clip gradients to prevent exploding gradients
        nn.utils.clip_grad_norm_(decoder.parameters(), max_norm=5)
        nn.utils.clip_grad_norm_(encoder.parameters(), max_norm=5)

        optimizer.step()

        total_loss += loss.item()
        # Print training info every 100 steps
        if i % 100 == 0:
            print(f'Epoch [{epoch+1}/{num_epochs}], Step [{i}/{len(train_loader)}], Loss: {loss.item():.4f}')

    # Compute average training loss
    avg_train_loss = total_loss / len(train_loader)
    train_losses.append(avg_train_loss)
    print(f'Epoch [{epoch+1}/{num_epochs}], Training Loss: {avg_train_loss:.4f}')

    # Evaluate on validation set
    val_loss = evaluate(encoder, decoder, val_loader)
    val_losses.append(val_loss)
    print(f'Epoch [{epoch+1}/{num_epochs}], Validation Loss: {val_loss:.4f}')
    # Calculate BLEU and METEOR scores on validation set
    bleu_score = calculate_bleu_score(
        encoder, decoder, image_dir, val_images, val_image2captions, transform, word2idx, idx2word
    )
    val_bleu_scores.append(bleu_score)

    print(f'Epoch [{epoch+1}/{num_epochs}], Validation BLEU Score: {bleu_score:.4f}')

    # Update learning rate scheduler
    scheduler.step()
# Out:
# Epoch [1/10], Step [0/885], Loss: 9.0473
# Epoch [1/10], Step [100/885], Loss: 5.8108
# Epoch [1/10], Step [200/885], Loss: 5.4508
# Epoch [1/10], Step [300/885], Loss: 5.2121
# Epoch [1/10], Step [400/885], Loss: 5.2443
# Epoch [1/10], Step [500/885], Loss: 5.3469
# Epoch [1/10], Step [600/885], Loss: 5.2425
# Epoch [1/10], Step [700/885], Loss: 4.9990
# Epoch [1/10], Step [800/885], Loss: 5.0528
# Epoch [1/10], Training Loss: 5.5520
# Epoch [1/10], Validation Loss: 4.8604
# Epoch [1/10], Validation BLEU Score: 0.0554
# Epoch [2/10], Step [0/885], Loss: 4.4583
# Epoch [2/10], Step [100/885], Loss: 4.5220
# Epoch [2/10], Step [200/885], Loss: 4.8067
# Epoch [2/10], Step [300/885], Loss: 4.4770
# Epoch [2/10], Step [400/885], Loss: 4.5891
# Epoch [2/10], Step [500/885], Loss: 4.5692
# Epoch [2/10], Step [600/885], Loss: 4.5700
# Epoch [2/10], Step [700/885], Loss: 4.2347
# Epoch [2/10], Step [800/885], Loss: 4.1930
# Epoch [2/10], Training Loss: 4.5849
# Epoch [2/10], Validation Loss: 4.3481
# Epoch [2/10], Validation BLEU Score: 0.0275
# Epoch [3/10], Step [0/885], Loss: 4.4902
# Epoch [3/10], Step [100/885], Loss: 4.5578
# Epoch [3/10], Step [200/885], Loss: 4.2275
# Epoch [3/10], Step [300/885], Loss: 4.3955
# Epoch [3/10], Step [400/885], Loss: 4.2930
# Epoch [3/10], Step [500/885], Loss: 4.2911
# Epoch [3/10], Step [600/885], Loss: 3.9812
# Epoch [3/10], Step [700/885], Loss: 4.1582
# Epoch [3/10], Step [800/885], Loss: 3.8373
# Epoch [3/10], Training Loss: 4.1964
# Epoch [3/10], Validation Loss: 4.0802
# Epoch [3/10], Validation BLEU Score: 0.0401
# Epoch [4/10], Step [0/885], Loss: 4.2213
# Epoch [4/10], Step [100/885], Loss: 3.9534
# Epoch [4/10], Step [200/885], Loss: 4.2220
# Epoch [4/10], Step [300/885], Loss: 3.8393
# Epoch [4/10], Step [400/885], Loss: 4.0731
# Epoch [4/10], Step [500/885], Loss: 3.5924
# Epoch [4/10], Step [600/885], Loss: 4.1035
# Epoch [4/10], Step [700/885], Loss: 3.8657
# Epoch [4/10], Step [800/885], Loss: 3.8506
# Epoch [4/10], Training Loss: 3.9717
# Epoch [4/10], Validation Loss: 3.9176
# Epoch [4/10], Validation BLEU Score: 0.0386
# Epoch [5/10], Step [0/885], Loss: 4.1399
# Epoch [5/10], Step [100/885], Loss: 3.9670
# Epoch [5/10], Step [200/885], Loss: 3.7193
# Epoch [5/10], Step [300/885], Loss: 3.6896
# Epoch [5/10], Step [400/885], Loss: 3.8036
# Epoch [5/10], Step [500/885], Loss: 3.9475
# Epoch [5/10], Step [600/885], Loss: 3.7721
# Epoch [5/10], Step [700/885], Loss: 3.7129
# Epoch [5/10], Step [800/885], Loss: 3.6763
# Epoch [5/10], Training Loss: 3.8133
# Epoch [5/10], Validation Loss: 3.7928
# Epoch [5/10], Validation BLEU Score: 0.1032
# Epoch [6/10], Step [0/885], Loss: 3.9503
# Epoch [6/10], Step [100/885], Loss: 3.9116
# Epoch [6/10], Step [200/885], Loss: 3.6926
# Epoch [6/10], Step [300/885], Loss: 3.5213
# Epoch [6/10], Step [400/885], Loss: 3.4359
# Epoch [6/10], Step [500/885], Loss: 3.9217
# Epoch [6/10], Step [600/885], Loss: 3.8098
# Epoch [6/10], Step [700/885], Loss: 3.6831
# Epoch [6/10], Step [800/885], Loss: 3.7712
# Epoch [6/10], Training Loss: 3.7134
# Epoch [6/10], Validation Loss: 3.7717
# Epoch [6/10], Validation BLEU Score: 0.0964
# Epoch [7/10], Step [0/885], Loss: 3.6253
# Epoch [7/10], Step [100/885], Loss: 3.8558
# Epoch [7/10], Step [200/885], Loss: 3.5308
# Epoch [7/10], Step [300/885], Loss: 3.7339
# Epoch [7/10], Step [400/885], Loss: 3.5118
# Epoch [7/10], Step [500/885], Loss: 3.7586
# Epoch [7/10], Step [600/885], Loss: 3.8823
# Epoch [7/10], Step [700/885], Loss: 3.7436
# Epoch [7/10], Step [800/885], Loss: 3.6909
# Epoch [7/10], Training Loss: 3.6979
# Epoch [7/10], Validation Loss: 3.7600
# Epoch [7/10], Validation BLEU Score: 0.1017
# Epoch [8/10], Step [0/885], Loss: 3.5339
# Epoch [8/10], Step [100/885], Loss: 3.5705
# Epoch [8/10], Step [200/885], Loss: 3.5330
# Epoch [8/10], Step [300/885], Loss: 3.6549
# Epoch [8/10], Step [400/885], Loss: 3.9136
# Epoch [8/10], Step [500/885], Loss: 3.4428
# Epoch [8/10], Step [600/885], Loss: 3.6819
# Epoch [8/10], Step [700/885], Loss: 3.5942
# Epoch [8/10], Step [800/885], Loss: 3.5619
# Epoch [8/10], Training Loss: 3.6852
# Epoch [8/10], Validation Loss: 3.7512
# Epoch [8/10], Validation BLEU Score: 0.1166
# Epoch [9/10], Step [0/885], Loss: 3.7164
# Epoch [9/10], Step [100/885], Loss: 3.6096
# Epoch [9/10], Step [200/885], Loss: 3.9019
# Epoch [9/10], Step [300/885], Loss: 3.4968
# Epoch [9/10], Step [400/885], Loss: 3.7983
# Epoch [9/10], Step [500/885], Loss: 3.7304
# Epoch [9/10], Step [600/885], Loss: 3.6764
# Epoch [9/10], Step [700/885], Loss: 3.8667
# Epoch [9/10], Step [800/885], Loss: 3.4220
# Epoch [9/10], Training Loss: 3.6723
# Epoch [9/10], Validation Loss: 3.7391
# Epoch [9/10], Validation BLEU Score: 0.1197
# Epoch [10/10], Step [0/885], Loss: 3.5640
# Epoch [10/10], Step [100/885], Loss: 3.6298
# Epoch [10/10], Step [200/885], Loss: 3.5422
# Epoch [10/10], Step [300/885], Loss: 3.6186
# Epoch [10/10], Step [400/885], Loss: 3.5209
# Epoch [10/10], Step [500/885], Loss: 3.4160
# Epoch [10/10], Step [600/885], Loss: 3.8312
# Epoch [10/10], Step [700/885], Loss: 3.5026
# Epoch [10/10], Step [800/885], Loss: 3.5014
# Epoch [10/10], Training Loss: 3.6601
# Epoch [10/10], Validation Loss: 3.7299
# Epoch [10/10], Validation BLEU Score: 0.1213

# %% [markdown]
# # Plots

# %%
epochs = range(1, num_epochs + 1)

plt.figure(figsize=(12, 5))
plt.plot(epochs, train_losses, label='Training Loss')
plt.plot(epochs, val_losses, label='Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Training and Validation Loss Over Epochs')
plt.legend()
plt.show()

# Plotting BLEU 
plt.figure(figsize=(12, 5))
plt.plot(epochs, val_bleu_scores, label='Validation BLEU Score')
plt.xlabel('Epoch')
plt.ylabel('Score')
plt.title('Validation BLEU Over Epochs')
plt.legend()
plt.show()

# %% [markdown]
# # Testing the Model On Test Dataset

# %%
def generate_caption(encoder, decoder, image, word2idx, idx2word, max_length=20):
    # Set the models to evaluation mode
    encoder.eval()
    decoder.eval()
    with torch.no_grad():
        # Move the image tensor to the appropriate device and add a batch dimension
        image = image.to(device).unsqueeze(0)
        # Extract features from the image using the encoder
        features = encoder(image)
        # Generate word IDs for the caption using the decoder
        sampled_ids = generate_caption_ids(decoder, features, word2idx, max_length)
        # Convert word IDs to words
        sampled_caption = [idx2word.get(word_id, '<unk>') for word_id in sampled_ids]

        # Remove special tokens from the caption
        sampled_caption = [word for word in sampled_caption if word not in ['<start>', '<end>', '<pad>']]
    # Join the words to form the final caption string
    return ' '.join(sampled_caption)

# %%
sample_image_name = test_images[0]  
# Construct the full image path
image_path = os.path.join(image_dir, sample_image_name)
# Open the image and convert it to RGB
image = Image.open(image_path).convert('RGB')
# Apply the same transformations used during training
image_tensor = transform(image)

# Generate caption for the sample image
caption = generate_caption(encoder, decoder, image_tensor, word2idx, idx2word)

# Display the image and the generated caption
plt.imshow(image)
plt.axis('off')  # Hide axis ticks and labels
plt.title('Generated Caption:\n' + caption)
plt.show()

# %%
sample_image_name = test_images[33]  
# Construct the full image path
image_path = os.path.join(image_dir, sample_image_name)
# Open the image and convert it to RGB
image = Image.open(image_path).convert('RGB')
# Apply the same transformations used during training
image_tensor = transform(image)

# Generate caption for the sample image
caption = generate_caption(encoder, decoder, image_tensor, word2idx, idx2word)

# Display the image and the generated caption
plt.imshow(image)
plt.axis('off')  # Hide axis ticks and labels
plt.title('Generated Caption:\n' + caption)
plt.show()

# %%
sample_image_name = test_images[90]  
# Construct the full image path
image_path = os.path.join(image_dir, sample_image_name)
# Open the image and convert it to RGB
image = Image.open(image_path).convert('RGB')
# Apply the same transformations used during training
image_tensor = transform(image)

# Generate caption for the sample image
caption = generate_caption(encoder, decoder, image_tensor, word2idx, idx2word)

# Display the image and the generated caption
plt.imshow(image)
plt.axis('off')  # Hide axis ticks and labels
plt.title('Generated Caption:\n' + caption)
plt.show()

# %%
sample_image_name = test_images[4]  
# Construct the full image path
image_path = os.path.join(image_dir, sample_image_name)
# Open the image and convert it to RGB
image = Image.open(image_path).convert('RGB')
# Apply the same transformations used during training
image_tensor = transform(image)

# Generate caption for the sample image
caption = generate_caption(encoder, decoder, image_tensor, word2idx, idx2word)

# Display the image and the generated caption
plt.imshow(image)
plt.axis('off')  # Hide axis ticks and labels
plt.title('Generated Caption:\n' + caption)
plt.show()

# %%
bleu_score_test = calculate_bleu_score(
    encoder, decoder, image_dir, test_images, test_image2captions, transform, word2idx, idx2word
)
print("Bleu Score for the test data : ",round(bleu_score_test,2))
# Out:
# Bleu Score for the test data :  0.13
